# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.arange(0, 10, 0.01)

# notice that nrows = number
# of images
plt.subplot(3, 1, 1)
plt.plot(x, np.sin(x))
 
# ncols stays as 1 
plt.subplot(3, 1, 2)
plt.plot(x, np.cos(x))
 
# each image has a unique 
# index
plt.subplot(3, 1, 3)
plt.plot(x, x)
 
plt.show()

# %% [markdown]
# ### Grid Plots

# %%
plt.subplot(2, 2, 1)
plt.plot(x, np.sin(x))

plt.subplot(2, 2, 2)
plt.plot(x, np.cos(x))

plt.subplot(2, 2, 3)
plt.plot(x, x)

plt.subplot(2, 2, 4)
plt.plot(x, 5-x)

plt.show()

# %%
fig = plt.figure()
plt.plot(x, x-5)

plt.title('Not so Tiny')
fig.add_subplot(2, 2, 4)
plt.plot(x, 5-x)

plt.title('Tiny Plot')
plt.show()

# %%
plt.subplot(221)
plt.plot(x, np.sin(x))

plt.subplot(222)
plt.plot(x, np.cos(x))

plt.subplot(223)
plt.plot(x, x)

plt.subplot(224)
plt.plot(x, 5-x)
plt.show()

# %% [markdown]
# ## Multiple Subplots
#
# ### 1-D Array of Subplots

# %%
x = [1, 2, 3]
y = [0, 1, 0]
z = [1, 0, 1]

fig, ax = plt.subplots(2)

ax[0].plot(x, y)
ax[1].plot(x, z)

# %% [markdown]
# ### Stacking in Two Directions

# %%
x = np.arange(0.0, 2.0, 0.01)
y = 1 + np.sin(2 * np.pi * x)

# Creating 6 subplots and unpacking the output array immediately
fig, ((ax1, ax2), (ax3, ax4), (ax5, ax6)) = plt.subplots(3, 2)
ax1.plot(x, y, color='orange')
ax2.plot(x, y, color='green')
ax3.plot(x, y, color='b')
ax4.plot(x, y, color='magenta')
ax5.plot(x, y, color='black')
ax6.plot(x, y, color='r')

# %% [markdown]
# ### Multiple Plots Same Figure

# %%
fig, axs = plt.subplots(2, 2)

# Now axs is a 2d array of Axes objects
axs[0, 0].plot([1,2,3], [4,5,6])
axs[0, 1].scatter([1,2,3], [4,5,6])
axs[1, 0].bar([1,2,3], [4,5,6])
axs[1, 1].hist([1,2,3], [4,5,6])
# Out:
# (array([0., 0.]), array([4., 5., 6.]), <BarContainer object of 2 artists>)

# %% [markdown]
# ## Title to Subplots
#
# ### Using set_title() method

# %%
x = np.array([1,2,3,4,5])

fig, ax = plt.subplots(2, 2)

ax[0, 0].plot(x, x)
ax[0, 1].plot(x, x*2)
ax[1, 0].plot(x, x*x)
ax[1, 1].plot(x, x*x*x)

# Set the title to subplots
ax[0, 0].set_title('Linear')
ax[0, 1].set_title('Double')
ax[1, 0].set_title('Square')
ax[1, 1].set_title('Cube')

fig.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Using title.set_text() method

# %%
fig, ax = plt.subplots(2, 2)

ax[0, 0].plot(x, x)
ax[0, 1].plot(x, x*2)
ax[1, 0].plot(x, x*x)
ax[1, 1].plot(x, x*x*x)

# Set the title to subplots
ax[0, 0].title.set_text('Linear')
ax[0, 1].title.set_text('Double')
ax[1, 0].title.set_text('Square')
ax[1, 1].title.set_text('Cube')

fig.tight_layout()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Using plt.gca().set_title() method

# %%
fig, ax = plt.subplots(2, 2)

# Set data with subplots and plot
title = ['Linear', 'Double', 'Square', 'Cube']
y = [x, x*2, x*x, x*x*x]

for i in range(4):
    # Subplots
    plt.subplot(2, 2, i+1)
    
    # Plotting (x, y)
    plt.plot(x, y[i])
    
    # Set the title to subplots
    plt.gca().set_title(title[i])
    
# Set spacing
fig.tight_layout()
plt.show()

# %% [markdown]
# ### Using plt.gca().title.set_text() method

# %%
fig, ax = plt.subplots(2, 2)

# Set data with subplots and plot
title = ['Linear', 'Double', 'Square', 'Cube']
y = [x, x*2, x*x, x*x*x]

for i in range(4):
    # Subplots
    plt.subplot(2, 2, i+1)
    
    # Plotting (x, y)
    plt.plot(x, y[i])
    
    # Set the title to subplots
    plt.gca().title.set_text(title[i])
    
# Set spacing
fig.tight_layout()
plt.show()

# %% [markdown]
# ## Single Title for All the Subplots

# %%
fig, ax = plt.subplots(2, 2)

ax[0][0].plot(np.random.randint(0, 5, 5), np.random.randint(0, 5, 5))
ax[0][1].plot(np.random.randint(0, 5, 5), np.random.randint(0, 5, 5))
ax[1][0].plot(np.random.randint(0, 5, 5), np.random.randint(0, 5, 5))
ax[1][1].plot(np.random.randint(0, 5, 5), np.random.randint(0, 5, 5))

fig.suptitle('Single Main Title for All Subplots', fontsize = 30)
plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 5))

x1 = [1,2,3,4,5,6]
y1 = [45, 34, 30, 45, 50, 38]
y2 = [36, 28, 30, 40, 38, 48]

labels = ['Student 1', 'Student 2']

# Add title to subplot
fig.suptitle('Student marks in different subjects', fontsize=30)

# Creating the subplots
l1 = ax1.plot(x1, y1, 'o-', color='g')
l2 = ax2.plot(x1, y1, 'o-')

fig.legend([l1, l2], labels=labels, loc='upper right')
plt.subplots_adjust(right=0.9)

plt.show()
# Out:
# C:\Users\IDEAPAD GAMING\AppData\Local\Temp\ipykernel_21284\3931843776.py:16: UserWarning: You have mixed positional and keyword arguments, some input may be discarded.
#   fig.legend([l1, l2], labels=labels, loc='upper right')

# %% [markdown]
# ## Different Subplot Sizes
#
# ### Gridspec

# %%
from matplotlib import gridspec

fig = plt.figure()

fig. set_figheight(8)
fig.set_figwidth(8)

spec = gridspec.GridSpec(ncols=2, nrows=2, width_ratios=[2, 1],
                         wspace=0.5, hspace=0.5, height_ratios=[1,2])

x = np.arange(0, 10, 0.1)
y = np.cos(x)

ax0 = fig.add_subplot(spec[0])
ax0.plot(x, y)

ax1 = fig.add_subplot(spec[1])
ax1.plot(x, y)

ax2 = fig.add_subplot(spec[2])
ax2.plot(x, y)

ax3 = fig.add_subplot(spec[3])
ax3.plot(x, y)

plt.show()

# %% [markdown]
# ### gridspec_kw

# %%
# Setting different parameters to adjust each grid
fig, ax = plt.subplots(nrows=2, ncols=2, figsize=(7,7),
                       gridspec_kw={'width_ratios': [3,3],
                                   'height_ratios': [3,3],
                                   'wspace': 0.4,
                                   'hspace': 0.4})

x = np.arange(0, 10, 0.1)
y = np.tan(x)

ax[0, 0].plot(x, y)
ax[0, 1].plot(x, y)
ax[1, 0].plot(x, y)
ax[1, 1].plot(x, y)

plt.show()

# %% [markdown]
# ### subplot2grid
#
# Provides more flexibility

# %%
fig = plt.figure()
fig.set_figheight(6)
fig.set_figwidth(6)
 
ax1 = plt.subplot2grid(shape=(3, 3), loc=(0, 0), colspan=3)
ax2 = plt.subplot2grid(shape=(3, 3), loc=(1, 0), colspan=1)
ax3 = plt.subplot2grid(shape=(3, 3), loc=(1, 2), rowspan=2)
ax4 = plt.subplot2grid((3, 3), (2, 0))
ax5 = plt.subplot2grid((3, 3), (2, 1), colspan=1)

x = np.arange(0, 10, 0.1)
y = np.cos(x)

ax1.plot(x, y)
ax1.set_title('ax1')
ax2.plot(x, y)
ax2.set_title('ax2')
ax3.plot(x, y)
ax3.set_title('ax3')
ax4.plot(x, y)
ax4.set_title('ax4')
ax5.plot(x, y)
ax5.set_title('ax5')

plt.tight_layout()

plt.show()

# %% [markdown]
# ## Spacing between subplots
#
# ### Using tight_layout() method to set the spacing

# %%
x = np.array([1,2,3,4,5])

fig, ax = plt.subplots(2,2)

ax[0,0].plot(x, x)
ax[0,1].plot(x, x*2)
ax[1,0].plot(x, x*x)
ax[1,1].plot(x, x*x*x)

fig.tight_layout()
plt.show()

# %% [markdown]
# ### Using pad

# %%
x = np.array([1,2,3,4,5])

fig, ax = plt.subplots(2,2)

ax[0,0].plot(x, x)
ax[0,1].plot(x, x*2)
ax[1,0].plot(x, x*x)
ax[1,1].plot(x, x*x*x)

fig.tight_layout(pad=5.0)
plt.show()

# %% [markdown]
# ### Using subplots_adjust()

# %%
x = np.array([1,2,3,4,5])

fig, ax = plt.subplots(2,2)

ax[0,0].plot(x, x)
ax[0,1].plot(x, x*2)
ax[1,0].plot(x, x*x)
ax[1,1].plot(x, x*x*x)

plt.subplots_adjust(left=0.1, bottom=0.1, right=0.9,
                    top=0.9, wspace=0.4, hspace=0.4)
plt.show()

# %% [markdown]
# ### Using subplots_tool()

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

fig, axs = plt.subplots(2, 2)

axs[0, 0].imshow(np.random.random((100, 100)))

axs[0, 1].imshow(np.random.random((100, 100)))

axs[1, 0].imshow(np.random.random((100, 100)))

axs[1, 1].imshow(np.random.random((100, 100)))

plt.subplot_tool()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21284\1390210908.py in <module>
#      12 axs[1, 1].imshow(np.random.random((100, 100)))
#      13
# ---> 14 plt.subplot_tool()
#      15 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot_tool(targetfig)
#    1663         return tb.trigger_tool("subplots")
#    1664     else:
# -> 1665         raise ValueError("subplot_tool can only be launched for figures with "
#    1666                          "an associated toolbar")
#    1667
#
# ValueError: subplot_tool can only be launched for figures with an associated toolbar

# %% [markdown]
# ### Using constrained_layout()

# %%
x = np.array([1,2,3,4,5])

fig, ax = plt.subplots(2,2, constrained_layout=True)

ax[0,0].plot(x, x)
ax[0,1].plot(x, x*2)
ax[1,0].plot(x, x*x)
ax[1,1].plot(x, x*x*x)

plt.show()
